# %%
import pandas as pd

# %%
df = pd.read_csv('인천식당_카테고리.csv',encoding = 'euc-kr')

# %%
df = df.drop(columns='_menu_text_combined')

# %%
df.head(3)
# Out:
#        식당명 행정구역                     도로명 주소        lat         lon  \
# 0    편가네된장  강화군  인천광역시 강화군 화도면 가능포로89번길 11  37.640677  126.419384
# 1  카페힐로 서창  남동구          인천광역시 남동구 서창남로 69  37.425347  126.748690
# 2   장흥숯불장어  강화군     인천광역시 강화군 길상면 장흥로 11-8  37.611824  126.518423
#
#                                                식당 설명  \
# 0  강화 맛집. 편가네 된장. 4대째 내려오는 전통방식 그대로국내산 재료를 엄선해 화학...
# 1  홈메이드 브런치 카페힐로는 주문과 동시에 신선하고 건강한 재료로 조리되어 제공되며,...
# 2  장흥숯불장어는 30년의 전통과 따라올 수 없는 맛으로 많은 고객층을 확보하고 있는 ...
#
#                                  영업 시간                      휴일 정보  \
# 0  평일 10:00-20:00 / 주말,공휴일 09:00-20:00  매주 수요일(공휴일 제외) / 명절 당일 휴무
# 1                          09:00-20:00                        NaN
# 2                        11:00 ~ 22:00                    첫째주 월요일
#
#   top_category sub_category
# 0           한식            탕
# 1          디저트         카페/빵
# 2           한식           고기

# %%
df = df.drop(columns='휴일 정보')

# %%
df.head(3)
# Out:
#        식당명 행정구역                     도로명 주소        lat         lon  \
# 0    편가네된장  강화군  인천광역시 강화군 화도면 가능포로89번길 11  37.640677  126.419384
# 1  카페힐로 서창  남동구          인천광역시 남동구 서창남로 69  37.425347  126.748690
# 2   장흥숯불장어  강화군     인천광역시 강화군 길상면 장흥로 11-8  37.611824  126.518423
#
#                                                식당 설명  \
# 0  강화 맛집. 편가네 된장. 4대째 내려오는 전통방식 그대로국내산 재료를 엄선해 화학...
# 1  홈메이드 브런치 카페힐로는 주문과 동시에 신선하고 건강한 재료로 조리되어 제공되며,...
# 2  장흥숯불장어는 30년의 전통과 따라올 수 없는 맛으로 많은 고객층을 확보하고 있는 ...
#
#                                  영업 시간 top_category sub_category
# 0  평일 10:00-20:00 / 주말,공휴일 09:00-20:00           한식            탕
# 1                          09:00-20:00          디저트         카페/빵
# 2                        11:00 ~ 22:00           한식           고기

# %%
# '장어'라는 단어가 '식당명' 또는 '식당설명'에 포함된 행 찾기
mask = df['식당명'].str.contains('장어', na=False) | df['식당 설명'].str.contains('장어', na=False)

# 조건에 맞는 행의 'top카테고리'와 'sub카테고리' 컬럼 값 지정
df.loc[mask, 'top_category'] = '한식'
df.loc[mask, 'sub_category'] = '장어'

# %%
df.head(3)
# Out:
#        식당명 행정구역                     도로명 주소        lat         lon  \
# 0    편가네된장  강화군  인천광역시 강화군 화도면 가능포로89번길 11  37.640677  126.419384
# 1  카페힐로 서창  남동구          인천광역시 남동구 서창남로 69  37.425347  126.748690
# 2   장흥숯불장어  강화군     인천광역시 강화군 길상면 장흥로 11-8  37.611824  126.518423
#
#                                                식당 설명  \
# 0  강화 맛집. 편가네 된장. 4대째 내려오는 전통방식 그대로국내산 재료를 엄선해 화학...
# 1  홈메이드 브런치 카페힐로는 주문과 동시에 신선하고 건강한 재료로 조리되어 제공되며,...
# 2  장흥숯불장어는 30년의 전통과 따라올 수 없는 맛으로 많은 고객층을 확보하고 있는 ...
#
#                                  영업 시간 top_category sub_category
# 0  평일 10:00-20:00 / 주말,공휴일 09:00-20:00           한식            탕
# 1                          09:00-20:00          디저트         카페/빵
# 2                        11:00 ~ 22:00           한식           장어

# %%
# '장어'라는 단어가 '식당명' 또는 '식당설명'에 포함된 행 찾기
mask = df['식당명'].str.contains('가든', na=False) | df['식당 설명'].str.contains('가든', na=False)

# 조건에 맞는 행의 'top카테고리'와 'sub카테고리' 컬럼 값 지정
df.loc[mask, 'top_category'] = '한식'
df.loc[mask, 'sub_category'] = '고기'

# %%
df.head()
# Out:
#        식당명 행정구역                     도로명 주소        lat         lon  \
# 0    편가네된장  강화군  인천광역시 강화군 화도면 가능포로89번길 11  37.640677  126.419384
# 1  카페힐로 서창  남동구          인천광역시 남동구 서창남로 69  37.425347  126.748690
# 2   장흥숯불장어  강화군     인천광역시 강화군 길상면 장흥로 11-8  37.611824  126.518423
# 3    바다앞농장   중구           인천광역시 중구 은하수로 10  37.492128  126.581271
# 4   달다1078  부평구         인천광역시 부평구 경인로 1078  37.486282  126.739534
#
#                                                식당 설명  \
# 0  강화 맛집. 편가네 된장. 4대째 내려오는 전통방식 그대로국내산 재료를 엄선해 화학...
# 1  홈메이드 브런치 카페힐로는 주문과 동시에 신선하고 건강한 재료로 조리되어 제공되며,...
# 2  장흥숯불장어는 30년의 전통과 따라올 수 없는 맛으로 많은 고객층을 확보하고 있는 ...
# 3  바다 앞에 자리한 작은 농장 카페이다. 직접 고른 원두로 로스팅한 특별한 커피와 매...
# 4  커피나 차(茶), 음료 및 디저트류와 함께 간단한 식사가 가능한 달다(daldha)...
#
#                                  영업 시간 top_category sub_category
# 0  평일 10:00-20:00 / 주말,공휴일 09:00-20:00           한식            탕
# 1                          09:00-20:00          디저트         카페/빵
# ...

# %%
# '장어'라는 단어가 '식당명' 또는 '식당설명'에 포함된 행 찾기
mask = df['식당명'].str.contains('중식', na=False) | df['식당 설명'].str.contains('중식', na=False)

# 조건에 맞는 행의 'top카테고리'와 'sub카테고리' 컬럼 값 지정
df.loc[mask, 'top_category'] = '중식'
df.loc[mask, 'sub_category'] = '면'

# %%
# '장어'라는 단어가 '식당명' 또는 '식당설명'에 포함된 행 찾기
mask = df['식당명'].str.contains('피자', na=False) | df['식당 설명'].str.contains('피자', na=False)

# 조건에 맞는 행의 'top카테고리'와 'sub카테고리' 컬럼 값 지정
df.loc[mask, 'top_category'] = '양식'
df.loc[mask, 'sub_category'] = '피자'

# %%
# '장어'라는 단어가 '식당명' 또는 '식당설명'에 포함된 행 찾기
mask = df['식당명'].str.contains('한정식', na=False) | df['식당 설명'].str.contains('한정식', na=False)

# 조건에 맞는 행의 'top카테고리'와 'sub카테고리' 컬럼 값 지정
df.loc[mask, 'top_category'] = '한식'
df.loc[mask, 'sub_category'] = '밥류'

# %%
# '장어'라는 단어가 '식당명' 또는 '식당설명'에 포함된 행 찾기
mask = df['식당명'].str.contains('스시', na=False) | df['식당 설명'].str.contains('스시', na=False)

# 조건에 맞는 행의 'top카테고리'와 'sub카테고리' 컬럼 값 지정
df.loc[mask, 'top_category'] = '일식'
df.loc[mask, 'sub_category'] = '초밥'

# %%
# '장어'라는 단어가 '식당명' 또는 '식당설명'에 포함된 행 찾기
mask = df['식당명'].str.contains('게장', na=False) | df['식당 설명'].str.contains('게장', na=False)

# 조건에 맞는 행의 'top카테고리'와 'sub카테고리' 컬럼 값 지정
df.loc[mask, 'top_category'] = '한식'
df.loc[mask, 'sub_category'] = '밥류'

# %%
df['top_category'].unique()
# Out:
# array(['한식', '디저트', '양식', '일식', '기타', '중식'], dtype=object)

# %%
df['sub_category'].unique()
# Out:
# array(['밥류', '카페/빵', '장어', '고기', '면', '탕', '생선', '기타', '패스트푸드', '초밥',
#        '피자', '치킨', '분식'], dtype=object)

# %%
# '장어'라는 단어가 '식당명' 또는 '식당설명'에 포함된 행 찾기
mask = df['식당명'].str.contains('분식', na=False)

# 조건에 맞는 행의 'top카테고리'와 'sub카테고리' 컬럼 값 지정
df.loc[mask, 'top_category'] = '기타'
df.loc[mask, 'sub_category'] = '분식'

# %%
# '장어'라는 단어가 '식당명' 또는 '식당설명'에 포함된 행 찾기
mask = df['식당명'].str.contains('만두', na=False)

# 조건에 맞는 행의 'top카테고리'와 'sub카테고리' 컬럼 값 지정
df.loc[mask, 'top_category'] = '한식'
df.loc[mask, 'sub_category'] = '기타'

# %%
df.head(3)
# Out:
#        식당명 행정구역                     도로명 주소        lat         lon  \
# 0    편가네된장  강화군  인천광역시 강화군 화도면 가능포로89번길 11  37.640677  126.419384
# 1  카페힐로 서창  남동구          인천광역시 남동구 서창남로 69  37.425347  126.748690
# 2   장흥숯불장어  강화군     인천광역시 강화군 길상면 장흥로 11-8  37.611824  126.518423
#
#                                                식당 설명  \
# 0  강화 맛집. 편가네 된장. 4대째 내려오는 전통방식 그대로국내산 재료를 엄선해 화학...
# 1  홈메이드 브런치 카페힐로는 주문과 동시에 신선하고 건강한 재료로 조리되어 제공되며,...
# 2  장흥숯불장어는 30년의 전통과 따라올 수 없는 맛으로 많은 고객층을 확보하고 있는 ...
#
#                                  영업 시간 top_category sub_category
# 0  평일 10:00-20:00 / 주말,공휴일 09:00-20:00           한식           밥류
# 1                          09:00-20:00          디저트         카페/빵
# 2                        11:00 ~ 22:00           한식           장어

# %%
df.to_csv('인천식당_카테고리.csv', encoding='euc-kr')
