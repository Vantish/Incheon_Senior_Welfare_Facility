# %%
import pandas as pd

# %%
df = pd.read_csv('인천광역시_노인복지시설 현황.csv', encoding='euc-kr')

# %%
df.isna().sum()
# Out:
# 시설명       0
# 시설유형      4
# 도로명 주소    0
# lat       0
# lon       0
# 구군        0
# dtype: int64

# %%
df.dropna(subset=['시설유형'], inplace = True)

# %%
df.isna().sum()
# Out:
# 시설명       0
# 시설유형      0
# 도로명 주소    0
# lat       0
# lon       0
# 구군        0
# dtype: int64

# %%
df.to_csv('인천광역시_노인복지시설_현황.csv', index=False, encoding='euc-kr-sig')
