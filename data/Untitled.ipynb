# %%
import pandas as pd

# %%
df = pd.read_csv('인천광역시_사회복지시설 현황_20240131.csv', encoding='utf-8')

# %%
df.isna().sum()
# Out:
# 연번       0
# 관련법령     0
# 시설종류     0
# 시설명      0
# 군구명      0
# 주소       0
# lat     25
# lon     25
# 연락처     56
# dtype: int64

# %%
df.dropna(subset=['lat'], inplace = True)

# %%
df['lat'].isna().sum()
# Out:
# np.int64(0)

# %%
df.dropna(subset=['lon'], inplace = True)

# %%
df['lon'].isna().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#    연번       관련법령    시설종류        시설명   군구명                  주소        lat  \
# 0   1  국민기초생활보장법  지역자활센터   강화지역자활센터   강화군    강화군 강화읍 충렬사로 155  37.730076
# 1   2  국민기초생활보장법  지역자활센터   중구지역자활센터    중구       중구 제물량로 132-2  37.469707
# 2   3  국민기초생활보장법  지역자활센터   동구지역자활센터    동구   동구 송림로 78,5층(송림동)  37.475243
# 3   4  국민기초생활보장법  지역자활센터   희망지역자활센터  미추홀구    미추홀구 송림로 249, 4층  37.475241
# 4   5  국민기초생활보장법  지역자활센터  미추홀지역자활센터  미추홀구  미추홀구 인주대로 493, 3층   37.450906
#
#           lon           연락처
# 0  126.474310  032-934-1189
# 1  126.629344  032-763-1988
# 2  126.643524  032-761-0766
# 3  126.660637  032-867-8414
# 4  126.691516  032-888-0231

# %%
df = df[['시설종류','시설명','군구명','주소','lat','lon']]

# %%
df
# Out:
#                시설종류            시설명   군구명                                 주소  \
# 0            지역자활센터       강화지역자활센터   강화군                   강화군 강화읍 충렬사로 155
# 1            지역자활센터       중구지역자활센터    중구                      중구 제물량로 132-2
# 2            지역자활센터       동구지역자활센터    동구                  동구 송림로 78,5층(송림동)
# 3            지역자활센터       희망지역자활센터  미추홀구                   미추홀구 송림로 249, 4층
# 4            지역자활센터      미추홀지역자활센터  미추홀구                 미추홀구 인주대로 493, 3층
# ..              ...            ...   ...                                ...
# 632  정신재활시설(공동생활가정)           꿈을담다    서구  서달로179번길 12-9, 2동 101호(가정동,인향아파트)
# 633    정신재활시설(주간재활)       월산사회복귀시설   부평구                          평천로 319-5
# 634    정신재활시설(주간재활)            새누리   연수구               앵고개로 183 남동부수도사업소 2층
# 635    정신재활시설(주간재활)  남동정신재활시설 그루터기   남동구      담방서로 23번길 17, 남동구장애인복지관(별관3층)
# 636    정신재활시설(주간재활)          해피투게더   계양구                         길마로 60, 5층
#
#            lat         lon
# 0    37.730076  126.474310
# ...
