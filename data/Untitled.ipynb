# %%
import pandas as pd

# %%
df = pd.read_csv('인천광역시_노인복지시설 현황.csv', encoding='euc-kr')

# %%
df.isna().sum()
# Out:
# 시설명       0
# 시설유형      4
# 도로명 주소    0
# lat       0
# lon       0
# 구군        0
# dtype: int64

# %%
df.dropna(subset=['시설유형'], inplace = True)

# %%
df['시설유형'].isna().sum()
# Out:
# np.int64(0)

# %%
df.to_csv('인천광역시_노인복지시설_현황_최종.csv', index=False, encoding='euc-kr')
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df.to_csv('인천광역시_노인복지시설_현황.csv', index=False, encoding='euc-kr-sig')
#
# File ~\miniconda3\envs\yh\lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
# Out:
# np.int64(4)
